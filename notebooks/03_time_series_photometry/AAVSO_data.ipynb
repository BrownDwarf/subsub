# %% [markdown]
# # AAVSO

# %%
# %load /Users/obsidian/Desktop/defaults.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
#! wget https://www.aavso.org/sites/default/files/tmp/aavsodata_5c5df877134a9.txt

# %%
#! mv aavsodata_5c5df877134a9.txt ../data/raw/

# %%
#! head ../data/raw/aavsodata_5c5df877134a9.txt

# %%
keep_cols = ['JD', 'Magnitude', 'Uncertainty', 'Band']
df = pd.read_csv('../data/raw/aavsodata_5c5df877134a9.txt', usecols=keep_cols)

v_band = df.Band == 'V'

df['mag']= df.Magnitude.str.lstrip('<').astype(np.float)
df['JD_like']= df.JD.astype(np.float)

df = df[v_band]
df = df.reset_index(drop=True)[['JD_like', 'mag', 'Uncertainty', 'Band']]

# %%
plt.plot(df[v_band].JD_like, df[v_band].mag, '.')
plt.ylim(13.8, 12)
# Out:
# (13.8, 12)

# %% [markdown]
# # From the demo on the K2SNE HLSP

# %%
# %matplotlib inline
import os, numpy, warnings
from astropy.io import fits
from astropy.table import Table
import pylab

# %%
def getimages(ra,dec,size=240,filters="griz",auxiliary="data,mask"):
    
    """Query hlspfilenames.py service to get a list of images
    
    ra, dec = position in degrees
    size = image size in pixels (0.25 arcsec/pixel)
    Returns a table with the results
    """
    
    service = "https://ps1images.stsci.edu/cgi-bin/hlspfilenames.py"
    url = ("{service}?ra={ra}&dec={dec}&size={size}&format=fits"
           "&auxiliary={auxiliary}&filters={filters}").format(**locals())
    table = Table.read(url, format='ascii')
    return table

def groupimages(table):
    
    """Group images by filter and image type
    
    Returns a nested dictionary:
    d[filter] = {'warp': rowlist, 'warp.mask': rowlist}
    where the row lists are sorted by mjd
    """
    
    d = {}
    for row in table:
        filter = row['filter']
        dsub = d.setdefault(filter,{})
        dsub.setdefault(row['type'],[]).append((row['mjd'], row))
    # sort row lists by MJD and strip off the mjd value
    for filter, entry in d.items():
        for filetype, flist in entry.items():
            flist.sort()
            entry[filetype] = [x[1] for x in flist]            
    return d

ra0 = 132.8056417
dec0 = 11.8611528
table = getimages(ra0,dec0,size=320*2)
print('Found', len(table), 'images')
print('Columns:', table.colnames)
groups = groupimages(table)
print(len(groups),'filters')
for filter, entry in groups.items():
    for filetype, flist in entry.items():
        print(filter,filetype,len(flist))
# Out:
# Downloading https://ps1images.stsci.edu/cgi-bin/hlspfilenames.py?ra=132.8056417&dec=11.8611528&size=640&format=fits&auxiliary=data,mask&filters=griz [Done]
# Found 96 images
# Columns: ['projcell', 'subcell', 'ra', 'dec', 'filter', 'mjd', 'type', 'filename', 'url']
# 4 filters
# r warp 10
# r warp.mask 10
# g warp 21
# g warp.mask 21
# i warp.mask 13
# i warp 13
# z warp 4
# z warp.mask 4

# %%
imagelist
# Out:
# ['https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58091.526078_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58097.495811_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58099.537285_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58111.503621_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58118.435830_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58126.422934_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58130.453289_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58134.404636_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58138.429098_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58140.558221_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58152.329595_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58154.371848_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits',
#  'https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58162.569570_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits']

# %%
def stackimages(imagelist, masklist):
    """Read FITS images from URLs and stack them
    
    imagelist is list of rows (from getimages) for the data
    masklist is corresponding list of rows for the stacks
    Returns stacked image, count of exposures in stack
    """
    n = len(imagelist)
    if n != len(masklist):
        raise ValueError("Mis-match in imagelist and masklist")
    if n == 0:
        raise ValueError("imagelist is empty")
    # assume all images are the same size
    im0 = fits.open(imagelist[0])[0].data
    mask0 = fits.open(masklist[0])[0].data
    # mask ought to be int but is float for some reason
    mask0[numpy.isnan(mask0)] = 0
    mask0 = mask0.astype(numpy.int32)
    imstack = numpy.zeros((n,im0.shape[0],im0.shape[1]), dtype=im0.dtype)
    imstack[0] = im0
    maskstack = numpy.zeros((n,im0.shape[0],im0.shape[1]), dtype=mask0.dtype)
    maskstack[0] = mask0
    for i in range(1,n):
        imstack[i] = fits.open(imagelist[i])[0].data
        mask0 = fits.open(masklist[i])[0].data
        mask0[numpy.isnan(mask0)] = 0
        maskstack[i] = mask0.astype(numpy.int32)
    # ignore all non-zero mask values in stack (conservative)
    imstack[maskstack != 0] = numpy.nan
    # suppress the annoying nanmean warning where all pixels are blank
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)
        im = numpy.nanmean(imstack,axis=0)
    count = numpy.isfinite(imstack).sum(axis=0)
    return im, count

filter = 'i'
fdict = groups[filter]
imagelist = [x['url'] for x in fdict['warp']]
masklist = [x['url'] for x in fdict['warp.mask']]
im, count = stackimages(iamagelist, masklist)
# Out:
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58091.526078_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58091.526078_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58097.495811_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58097.495811_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58099.537285_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58099.537285_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58111.503621_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58111.503621_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58118.435830_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58118.435830_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58126.422934_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58126.422934_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58130.453289_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58130.453289_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58134.404636_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58134.404636_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58138.429098_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58138.429098_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58140.558221_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58140.558221_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58152.329595_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58152.329595_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58154.371848_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58154.371848_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58162.569570_i_v1_wrp.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]
# Downloading https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?red=/hlsp/k2sne/skycells/1534/096/hlsp_k2sne_ps1_gpc1_skycell.1534.096-58162.569570_i_v1_mask.fits&ra=132.8056417&dec=11.8611528&size=640&format=fits [Done]

# %%
print('Number of blank pixels',(count==0).sum())
print('Image min max',numpy.nanmin(im),numpy.nanmax(im))
pylab.figure(1,(10,10))
pylab.imshow(numpy.arcsinh(im/10), cmap='hot')
# Out:
# Number of blank pixels 6131
# Image min max -21.426893 28240.47

# %%
! ls
# Out:
# Checking_SN_vals.ipynb
# CoolStars_plots.ipynb
# K2_C16_M67_lightcurve_search.ipynb
# K2_lightcurve_analysis.ipynb
# Pan-STARRS-C16.ipynb
# README.md
# Untitled.ipynb
# checking_batch_emcee_results.ipynb
# checking_results_run02.ipynb
# mastDownload
# plotting-batch-emcee-results.ipynb
# plotting-spottemp-fillingfactor-kde.ipynb
# subsub-manual-configuration_mcmc.ipynb
# subsubOMC.ipynb
# subsub_001-01_Just_look_at_it.ipynb
# subsub_004-01_spotcheck_MCMC.ipynb
# subsub_01-06_HDF5_by_order.ipynb
# subsub_ASASSN_photometry_analysis.ipynb
# subsub_checking_new_data.ipynb
# subsub_violin_plot_demo.ipynb

# %%
! ls mastDownload/

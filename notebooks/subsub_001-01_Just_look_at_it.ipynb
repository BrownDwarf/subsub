# %% [markdown]
# # subsub
# ## Task 1- Just look at the data
#
# Michael Gully-Santiago
# Saturday, July 2, 2016
#
# We're literally just going to plot the spectra.

# %% [markdown]
# ## Get the data
#
# There are 3 fits files from NG -> MGS on June 8, 2016, in an email titled "Sub-subgiant spectra".

# %%
! ls -1 ../data/raw/
# Out:
# S1063_o110.fits
# S1063_o113.fits
# S1063_o115.fits

# %%
from astropy.io import fits

# %%
hdu1 = fits.open('../data/raw/S1063_o110.fits')

# %%
hdu1.info()
# Out:
# Filename: ../data/raw/S1063_o110.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     214   (2048,)      float32

# %%
dat1 = hdu1[0]

# %%
dat1.data
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.], dtype=float32)

# %%
sns.set_context('notebook')

# %% [markdown]
# ### S1063_o110.fits

# %%
plt.plot(dat1.data)
plt.ylim(0,0.4)
# Out:
# (0, 0.4)

# %% [markdown]
# ### S1063_o113.fits

# %%
plt.plot(fits.open('../data/raw/S1063_o113.fits')[0].data)
plt.ylim(0,0.4)
# Out:
# (0, 0.4)

# %% [markdown]
# ### S1063_o115.fits

# %%
plt.plot(fits.open('../data/raw/S1063_o115.fits')[0].data)
plt.ylim(0,0.4)
# Out:
# (0, 0.4)

# %% [markdown]
# # Missing data
#
#
# We need:
# - Wavelength vector
# - Sigma vector
# - Trim off the noise, zeros, and `NaN`s, if any, on the ends.

# %% [markdown]
# ## The end.

# %% [markdown]
# ## Plotting spectra from the emcee results
#
# N. Gosnell 7-6-2018

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
import pandas as pd
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# The "good" orders right now are 106, 109, 116, and 119. We're re-running some orders to hopefully get rid of a bimodal distribution.
#
# Let's also try labeling some lines from the Arcturus line list

# %%
arct = pd.read_csv('/Users/ngosnell/Rayner2009_Arcturuslines.csv')

# %%
arct.wl = arct.wl * 10000
arct.head()
# Out:
#          wl    id
# 0  8027.028  Ti I
# 1  8030.128  Fe I
# 2  8030.499  Fe I
# 3  8048.243  Fe I
# 4  8049.814  Fe I

# %%
df = pd.read_csv('../sf/m106/output/mix_emcee/run01/models_ff-05_50_95.csv')

# %%
matchids = arct.loc[(arct['wl'] >= df.wl.min()) & (arct['wl'] <= df.wl.max())]
ids = list(matchids.id)
idwl = np.array(matchids.wl)

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite')
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
#for i in range(len(ids)):
#    plt.annotate(ids[i], (idwl[i], 0.4), xycoords='data')
#plt.annotate(arct.id[444], (arct.wl[444], 0.4), xycoords = 'data')
plt.legend(loc='best');

# %% [markdown]
# There are way more lines here than in the Arcturus list, so I'm not going to keep plotting them for now.

# %%
df = pd.read_csv('../sf/m109/output/mix_emcee/run01/models_ff-05_50_95.csv')

# %%
df.head()
# Out:
#        data            wl  model_comp05  model_cool05  model_hot05  \
# 0  0.203191  16370.098116      0.243818      0.016591     0.227227
# 1  0.216570  16370.217457      0.242403      0.016485     0.225918
# 2  0.228850  16370.336782      0.239211      0.016262     0.222950
# 3  0.234324  16370.456090      0.233470      0.015867     0.217603
# 4  0.222259  16370.575382      0.224766      0.015270     0.209495
#
#    model_comp50  model_cool50  model_hot50  model_comp95  model_cool95  \
# 0      0.244716      0.067617     0.177099      0.246601      0.103818
# 1      0.243327      0.067119     0.176208      0.245862      0.103411
# 2      0.240209      0.066168     0.174041      0.243679      0.102346
# 3      0.234527      0.064528     0.169999      0.239298      0.100343
# 4      0.225791      0.062040     0.163751      0.231792      0.096978
#
#    model_hot95
# 0     0.142783
# 1     0.142451
# 2     0.141332
# 3     0.138956
# 4     0.134814

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp50, label='Composite')
plt.plot(df.wl, df.model_cool50, label='Cool')
plt.plot(df.wl, df.model_hot50, label='Hot')
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m116/output/mix_emcee/run01/models_ff-05_50_95.csv')

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite')
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m119/output/mix_emcee/run01/models_ff-05_50_95.csv')

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite')
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m107/output/mix_emcee/run02/models_ff-05_50_95.csv')

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite')
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m110/output/mix_emcee/run02/models_ff-05_50_95.csv')

# %%
plt.figure(figsize=(10,4))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite', linewidth=2)
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
#plt.xlim(16355,16365)
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m113/output/mix_emcee/run02/models_ff-05_50_95.csv')

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite')
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m114/output/mix_emcee/run02/models_ff-05_50_95.csv')

# %%
plt.figure(figsize=(10,6))
plt.step(df.wl, df.data, label='data')
plt.plot(df.wl, df.model_comp95, label='Composite')
plt.plot(df.wl, df.model_cool95, label='Cool')
plt.plot(df.wl, df.model_hot95, label='Hot')
#plt.xlim(15720, 15740)
plt.legend(loc='best')

# %%
df = pd.read_csv('../sf/m118/output/mix_emcee/run02/models_ff-05_50_95.csv')

# %%
plt.rc('font', size=14)
plt.rc('axes', titlesize=16)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('legend', fontsize=10)
plt.rc('figure', titlesize=16)

plt.figure(figsize=(5,6))
plt.step(df.wl / 10000, df.data * (1. / 0.3), 
         label='IGRINS spectrum', color='#A9A9A9', linewidth=2)
plt.plot(df.wl / 10000, df.model_comp95* (1. / 0.3), 
         label='Composite fit', linewidth=3, color='#81219F')
plt.plot(df.wl / 10000, df.model_hot95* (1. / 0.3), 
         label='Ambient spectrum', color='#EB9952',linewidth=2)
plt.plot(df.wl / 10000, df.model_cool95* (1. / 0.3), 
         label='Spot spectrum', color='#C65B70', linewidth=2)
plt.xlim(1.5265,1.5287)
plt.ylim(0.0,1.1)
plt.xlabel("Wavelength (microns)")
plt.ylabel("Relative flux")
plt.legend(loc='best')
plt.title("Spots on a Sub-subgiant")
plt.tight_layout()
plt.savefig('../results/figs/Order118_badge.pdf', dpi=300);
